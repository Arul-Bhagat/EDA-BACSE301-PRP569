# %% [markdown]
# <a href="https://colab.research.google.com/github/Arul-Bhagat/EDA-BACSE301-PRP569/blob/main/Experiment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Create a dummy dataset with an outlier
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
data={
  'Age': [25, 30, 45, 35, 22, 45, 53, 23, 46],
 'Salary': [50000, 64000, 120000, 85000, 1200000, 85000, 67000, 69000, 45000]
}
df = pd.DataFrame(data)
print("Original Data:\n", df, "\n")
# Out:
# Original Data:
#     Age   Salary
# 0   25    50000
# 1   30    64000
# 2   45   120000
# 3   35    85000
# 4   22  1200000
# 5   45    85000
# 6   53    67000
# 7   23    69000
# 8   46    45000

# %%
# 2. Min-Max Scaling (Normalization)
min_max_scaler = MinMaxScaler()
df_min_max = pd.DataFrame(
 min_max_scaler.fit_transform(df),
 columns=df.columns
)
print("Min-Max Scaled Data:\n", df_min_max, "\n")
# Out:
# Min-Max Scaled Data:
#          Age    Salary
# 0  0.096774  0.004329
# 1  0.258065  0.016450
# 2  0.741935  0.064935
# 3  0.419355  0.034632
# 4  0.000000  1.000000
# 5  0.741935  0.034632
# 6  1.000000  0.019048
# 7  0.032258  0.020779
# 8  0.774194  0.000000

# %%
# 3. Z-score Standardization
standard_scaler=StandardScaler()
df_standard=pd.DataFrame(
    standard_scaler.fit_transform(df),
    columns=df.columns
)
print("Standradized Data:\n",df_standard,"\n")
# Out:
# Standradized Data:
#          Age    Salary
# 0 -1.006959 -0.418122
# 1 -0.549250 -0.378659
# 2  0.823876 -0.220806
# 3 -0.091542 -0.319464
# 4 -1.281584  2.823500
# 5  0.823876 -0.319464
# 6  1.556209 -0.370203
# 7 -1.190042 -0.364565
# 8  0.915417 -0.432216
